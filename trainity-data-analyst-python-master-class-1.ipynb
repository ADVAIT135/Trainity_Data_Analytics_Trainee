# %% [markdown]
# # Python Masterclass-1 Assignment

# %% [markdown]
# ## 1. Write a Python program to display "Hello, World!" on the console.

# %%
print("Hello World!!!")
# Out:
# Hello World!!!

# %% [markdown]
# ## 2. Write a Python program that prompts the user to enter two numbers, and
# ## then performs the following operations:
# ## Addition: Print the sum of the two numbers.
# ## Subtraction: Print the difference between the two numbers.
# ## Multiplication: Print the product of the two numbers.
# ## Division: Print the result of dividing the first number by the second number.

# %%
a = int(input("Enter the 1st number : "))
b = int(input("Enter the 2nd number : "))
print("Addition of ",a," and" , b, "is ",a+b)
print("Subtraction of ",b," from " , a, "is ",a-b)
print("Multiplication of ",a," and" , b, "is ",a*b)
print("Division of ",a," by" , b, "is ",a/b)
# Out:
# Enter the 1st number :  5
# Enter the 2nd number :  9
# Addition of  5  and 9 is  14
# Subtraction of  9  from  5 is  -4
# Multiplication of  5  and 9 is  45
# Division of  5  by 9 is  0.5555555555555556

# %% [markdown]
# ## 3.Write a Python program that calculates the area and perimeter of a
# ## rectangle. Prompt the user to enter the length and width of the rectangle, and
# ## then calculate and print the area and perimeter.

# %%
length = float(input("Enter the length of Rectangle"))
width = float(input("Enter the width of Rectangle"))
print("The Area of Reactangle with length",length,"units and width",width,"units is",length*width,"units^2")
# Out:
# Enter the length of Rectangle 98.9
# Enter the width of Rectangle 9.2
# The Area of Reactangle with length 98.9 units and width 9.2 units is 909.88 units^2

# %% [markdown]
# ## Optional Advanced-level question:
# ## Write a Python program to convert temperature in Celsius to Fahrenheit. The
# ## formula to convert Celsius to Fahrenheit is: F = (C * 9/5) + 32, where F is the
# ## temperature in Fahrenheit and C is the temperature in Celsius.

# %%
cel = float(input("Enter the temperature in Celsius: "))
fah = (cel * (9/5)) + 32
print("The Corresponding Fahrenheit temperature is",fah,"for the given Celsius temperature:",cel)
# Out:
# Enter the temperature in Celsius:  35.6
# The Corresponding Fahrenheit temperature is 96.08 for the given Celsius temperature: 35.6
